# %%
# prerpocessing datasets
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split


train_df = pd.read_csv('D:/Study/7318/a3/Recurrent-Neural-Networks-for-Stock-Price-Prediction/datasets/Google_Stock_Price_Train.csv')
test_df = pd.read_csv('D:/Study/7318/a3/Recurrent-Neural-Networks-for-Stock-Price-Prediction/datasets/Google_Stock_Price_Test.csv')


# transform date to datetime type as index
train_df['Date'] = pd.to_datetime(train_df['Date'])
test_df['Date'] = pd.to_datetime(test_df['Date'])
train_df.set_index('Date', inplace=True)
test_df.set_index('Date', inplace=True)

# set all features
features = ['Open', 'High', 'Low', 'Close', 'Volume']

# remove comma
train_df[features] = train_df[features].replace({',': ''}, regex=True).astype(float)
test_df[features] = test_df[features].replace({',': ''}, regex=True).astype(float)


# data normalization, create dataframe for data
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train_df[features])
test_scaled = scaler.transform(test_df[features])
train_scaled_df = pd.DataFrame(train_scaled, columns=features, index=train_df.index)
test_scaled_df = pd.DataFrame(test_scaled, columns=features, index=test_df.index)

# split train,val sets in 8/2
train_size = int(len(train_scaled_df) * 0.8)
train_data = train_scaled_df[:train_size]
val_data = train_scaled_df[train_size:]

# use past N days to predict next M dayts, create time series
def create_dataset(data, N=30, M=1):
    X, y = [], []
    for i in range(N, len(data) - M + 1):
        X.append(data[i-N:i])  
        y.append(data[i:i+M, 3]) # predict next M days close price
    return np.array(X), np.array(y)
    
X_train, y_train = create_dataset(train_data.values)
X_val, y_val = create_dataset(val_data.values)

print(f'X_train shape: {X_train.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'X_val shape: {X_val.shape}')
print(f'y_val shape: {y_val.shape}')
# Out:
# X_train shape: (976, 30, 5)
# y_train shape: (976, 1)
# X_val shape: (222, 30, 5)
# y_val shape: (222, 1)

# %%
print(test_df.info())
print(f"Scaler data_min: {scaler.data_min_}")
print(f"Scaler data_max: {scaler.data_max_}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20 entries, 2017-01-03 to 2017-01-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    20 non-null     float64
#  1   High    20 non-null     float64
#  2   Low     20 non-null     float64
#  3   Close   20 non-null     float64
#  4   Volume  20 non-null     float64
# dtypes: float64(5)
# memory usage: 960.0 bytes
# None
# Scaler data_min: [ 279.12  281.21  277.22  491.2  7900.  ]
# Scaler data_max: [8.16680e+02 8.16680e+02 8.05140e+02 1.21683e+03 2.49779e+07]

# %%
# Train LSTM model
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import math

# init LSTM model
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size  
        self.num_layers = num_layers    
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        lstm_out, _ = self.lstm(x, (h0, c0))
        out = self.fc(lstm_out[:, -1, :])  # get last time step output
        return out

# set para.
input_size = 5  
hidden_size = 64  
num_layers = 2  
output_size = 1  
num_epochs = 500  
batch_size = 32  
learning_rate = 0.001  

# use dataloader for auto slicing
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# loss function, optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = LSTMModel(input_size, hidden_size, num_layers, output_size).to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# train
train_losses = []
val_losses = []

# train
for epoch in range(num_epochs):
    model.train()

    for i in range(0, len(X_train_tensor), batch_size):
        batch_X = X_train_tensor[i:i+batch_size]
        batch_y = y_train_tensor[i:i+batch_size].unsqueeze(1)  

        # zero gradients
        optimizer.zero_grad()

        # forward pass
        outputs = model(batch_X)

        loss = criterion(outputs, batch_y)  # MSE loss calculation

        # backward pass
        loss.backward()

        # update weights
        optimizer.step()
    
    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')


# save model
torch.save(model.state_dict(), 'lstm_model.pth')

# %%
# test lstm mse,rmse

model.eval()
with torch.no_grad():

    test_outputs = model(X_val_tensor)
    mse = mean_squared_error(y_val_tensor.cpu(), test_outputs.cpu())
    rmse = math.sqrt(mse)
    
    print(f'MSE: {mse:.4f}')
    print(f'RMSE: {rmse:.4f}')
# Out:
# MSE: 0.0002
# RMSE: 0.0138

# %%
# predict next 30 days, from 1/1 to 1/31 2017, compare with acutal close data

import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import torch
import numpy as np


data_df = pd.read_csv('D:/Study/7318/a3/Recurrent-Neural-Networks-for-Stock-Price-Prediction/datasets/RealComparedatasets.csv')
data_df['Date'] = pd.to_datetime(data_df['Date'])
data_df.set_index('Date', inplace=True)

# only scaler close column, normalizaed 
features = ['Open', 'High', 'Low', 'Close', 'Volume']
data_df[features] = data_df[features].replace({',': ''}, regex=True).astype(float)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data_df[features])
close_scaler = MinMaxScaler(feature_range=(0, 1))
scaled_close = close_scaler.fit_transform(data_df[['Close']])
data_df['Scaled_Close'] = scaled_close


N = 30
X_input = scaled_data[-N:].reshape(1, N, len(features))  # reshape to (1, 30, 5)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
X_input_tensor = torch.Tensor(X_input).to(device)


model.eval()

with torch.no_grad():

    predicted_price = model(X_input_tensor)
    # print(f"Predicted scaled price: {predicted_price}")

    predicted_price = predicted_price.cpu().numpy()
    print(f"Predicted price in numpy array: {predicted_price}")

    # only fill close column
    predicted_price_with_zeros = np.zeros((1, len(features)))
    predicted_price_with_zeros[0, -1] = predicted_price[0, -1]  # only fill close column
    # print(f"Price with zeros for inverse transformation: {predicted_price_with_zeros}")

    # manual denormalization
    close_min = close_scaler.data_min_[0]
    close_max = close_scaler.data_max_[0]
    predicted_close_rescaled = close_min + (predicted_price[0, -1] * (close_max - close_min))
    print(f"Rescaled Close price (manually): {predicted_close_rescaled}")

    print(f"Predicted Close price for 2017-01-01: {predicted_close_rescaled:.2f}")
# Out:
# Predicted price in numpy array: [[0.48674688]]
# Rescaled Close price (manually): 772.2232715901732
# Predicted Close price for 2017-01-01: 772.22

# %%
# denormolization data and predict next 30 days

import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import torch
import numpy as np
import matplotlib.pyplot as plt



# model = LSTMModel(input_size, hidden_size, num_layers, output_size).to(device)
# model.load_state_dict(torch.load("lstm_model.pth"))
model.eval()

N = 30
X_input = scaled_data[-N:].reshape(1, N, len(features))  # reshape to (1, 30, 5)

X_input_tensor = torch.tensor(X_input, dtype=torch.float32).to(device)

predicted_prices = []
with torch.no_grad():
    for i in range(31):  
        predicted_price = model(X_input_tensor)  
        predicted_price = predicted_price.cpu().numpy()
        
        # denormalize 
        predicted_close_rescaled = close_scaler.inverse_transform(predicted_price)  
        predicted_prices.append(predicted_close_rescaled[0, 0])  
        
        # update window
        X_input = np.roll(X_input, shift=-1, axis=1)
        X_input[0, -1, -1] = predicted_price[0, -1] 
        X_input_tensor = torch.tensor(X_input, dtype=torch.float32).to(device)

test_data = pd.read_csv('D:/Study/7318/a3/Recurrent-Neural-Networks-for-Stock-Price-Prediction/datasets/Google_Stock_Price_Test.csv')
test_data['Date'] = pd.to_datetime(test_data['Date'])
test_data.set_index('Date', inplace=True)

# get the actual prices from the test dataset
actual_prices = test_data['Close'].values
actual_dates = test_data.index

predicted_prices_trimmed = predicted_prices[:len(test_data.index)]

# plot
plt.figure(figsize=(12, 6))
plt.plot(actual_dates, actual_prices, label='Actual Prices', color='blue', marker='o')
plt.plot(actual_dates, predicted_prices_trimmed, label='Predicted Prices', color='red', marker='x')
plt.title('Predicted vs Actual Close Prices for January 2017 (GRU)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# C:\Users\SpiderJockey\AppData\Local\Temp\ipykernel_22136\3209798552.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("lstm_model.pth"))

# %%
import pandas as pd
import matplotlib.pyplot as plt

# create dataframe
results = pd.DataFrame({
    'Date': test_data.index[:len(predicted_prices)],  # Ensure we match the length of predicted prices
    'Predicted Close': predicted_prices[:len(test_data.index)],  # Limit predictions to the length of actual data
    'Actual Close': actual_prices[:len(test_data.index)]  # Use actual closing prices
})

# calculate trend match
results['Trend Match'] = results.apply(
    lambda row: 'Match' if (
        (row['Predicted Close'] > row['Actual Close'] and results.iloc[row.name - 1]['Actual Close'] < row['Actual Close']) or
        (row['Predicted Close'] < row['Actual Close'] and results.iloc[row.name - 1]['Actual Close'] > row['Actual Close'])
    ) else 'Mismatch', axis=1
)


print(results)

matches = results['Trend Match'].value_counts().get('Match', 0)
mismatches = results['Trend Match'].value_counts().get('Mismatch', 0)
total = len(results)
accuracy = (matches / total) * 100

print(f"\nTrend Match Analysis:")
print(f"Total Predictions: {total}")
print(f"Matches: {matches}")
print(f"Mismatches: {mismatches}")
print(f"Trend Match Accuracy: {accuracy:.2f}%")
# Out:
#          Date  Predicted Close  Actual Close Trend Match
# 0  2017-01-03       772.223267        786.14       Match
# 1  2017-01-04       771.714417        786.90    Mismatch
# 2  2017-01-05       769.525696        794.02    Mismatch
# 3  2017-01-06       772.714539        806.15    Mismatch
# 4  2017-01-09       774.227295        806.65    Mismatch
# 5  2017-01-10       774.666748        804.79       Match
# 6  2017-01-11       775.063782        807.91    Mismatch
# 7  2017-01-12       776.106445        806.36       Match
# 8  2017-01-13       775.647705        807.88    Mismatch
# 9  2017-01-17       769.549377        804.61       Match
# 10 2017-01-18       763.243774        806.07    Mismatch
# 11 2017-01-19       760.743408        802.17       Match
# 12 2017-01-20       762.262512        805.02    Mismatch
# 13 2017-01-23       758.694641        819.31    Mismatch
# 14 2017-01-24       764.213928        823.87    Mismatch
# 15 2017-01-25       766.771973        835.67    Mismatch
# 16 2017-01-26       775.580872        832.15       Match
# 17 2017-01-27       777.403748        823.31       Match
# 18 2017-01-30       784.344116        802.32       Match
# 19 2017-01-31       786.481873        796.79       Match
#
# Trend Match Analysis:
# Total Predictions: 20
# Matches: 9
# Mismatches: 11
# Trend Match Accuracy: 45.00%

# %%
# train GRU model
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).to(device)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32).to(device)

batch_size = 64
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# init GRU
class GRUModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(GRUModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.gru(x, h0)  # GRU layer
        out = self.fc(out[:, -1, :])  # Use the output from the last time step
        return out

# set para.
input_size = X_train.shape[2]  # features
hidden_size = 50  # hidden state size
output_size = y_train.shape[1]  
num_layers = 2  # GRU layers
learning_rate = 0.001
num_epochs = 500

# loss function, optimizer
model = GRUModel(input_size, hidden_size, output_size, num_layers).to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    for X_batch, y_batch in train_loader:
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    
    train_loss /= len(train_loader)
    
    # validate
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            val_loss += loss.item()
    val_loss /= len(val_loader)
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

# save model
torch.save(model.state_dict(), "gru_model.pth")
# Out:
# Epoch [1/500], Train Loss: 0.0975, Val Loss: 0.0237
# Epoch [2/500], Train Loss: 0.0402, Val Loss: 0.0058
# Epoch [3/500], Train Loss: 0.0154, Val Loss: 0.0079
# Epoch [4/500], Train Loss: 0.0040, Val Loss: 0.0005
# Epoch [5/500], Train Loss: 0.0026, Val Loss: 0.0008
# Epoch [6/500], Train Loss: 0.0021, Val Loss: 0.0003
# Epoch [7/500], Train Loss: 0.0019, Val Loss: 0.0003
# Epoch [8/500], Train Loss: 0.0018, Val Loss: 0.0003
# Epoch [9/500], Train Loss: 0.0017, Val Loss: 0.0003
# Epoch [10/500], Train Loss: 0.0018, Val Loss: 0.0003
# Epoch [11/500], Train Loss: 0.0017, Val Loss: 0.0002
# Epoch [12/500], Train Loss: 0.0016, Val Loss: 0.0002
# Epoch [13/500], Train Loss: 0.0015, Val Loss: 0.0002
# Epoch [14/500], Train Loss: 0.0034, Val Loss: 0.0012
# Epoch [15/500], Train Loss: 0.0020, Val Loss: 0.0011
# Epoch [16/500], Train Loss: 0.0017, Val Loss: 0.0010
# Epoch [17/500], Train Loss: 0.0014, Val Loss: 0.0004
# Epoch [18/500], Train Loss: 0.0013, Val Loss: 0.0002
# Epoch [19/500], Train Loss: 0.0013, Val Loss: 0.0003
# Epoch [20/500], Train Loss: 0.0031, Val Loss: 0.0013
# Epoch [21/500], Train Loss: 0.0018, Val Loss: 0.0006
# Epoch [22/500], Train Loss: 0.0013, Val Loss: 0.0002
# Epoch [23/500], Train Loss: 0.0012, Val Loss: 0.0002
# Epoch [24/500], Train Loss: 0.0012, Val Loss: 0.0002
# Epoch [25/500], Train Loss: 0.0012, Val Loss: 0.0004
# Epoch [26/500], Train Loss: 0.0012, Val Loss: 0.0002
# Epoch [27/500], Train Loss: 0.0011, Val Loss: 0.0002
# Epoch [28/500], Train Loss: 0.0011, Val Loss: 0.0002
# Epoch [29/500], Train Loss: 0.0011, Val Loss: 0.0003
# Epoch [30/500], Train Loss: 0.0030, Val Loss: 0.0010
# Epoch [31/500], Train Loss: 0.0016, Val Loss: 0.0002
# Epoch [32/500], Train Loss: 0.0012, Val Loss: 0.0004
# Epoch [33/500], Train Loss: 0.0011, Val Loss: 0.0002
# Epoch [34/500], Train Loss: 0.0012, Val Loss: 0.0001
# Epoch [35/500], Train Loss: 0.0011, Val Loss: 0.0002
# Epoch [36/500], Train Loss: 0.0011, Val Loss: 0.0004
# Epoch [37/500], Train Loss: 0.0010, Val Loss: 0.0001
# Epoch [38/500], Train Loss: 0.0010, Val Loss: 0.0002
# Epoch [39/500], Train Loss: 0.0010, Val Loss: 0.0003
# Epoch [40/500], Train Loss: 0.0010, Val Loss: 0.0002
# Epoch [41/500], Train Loss: 0.0010, Val Loss: 0.0002
# Epoch [42/500], Train Loss: 0.0010, Val Loss: 0.0002
# Epoch [43/500], Train Loss: 0.0010, Val Loss: 0.0001
# Epoch [44/500], Train Loss: 0.0011, Val Loss: 0.0003
# Epoch [45/500], Train Loss: 0.0010, Val Loss: 0.0003
# Epoch [46/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [47/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [48/500], Train Loss: 0.0010, Val Loss: 0.0002
# Epoch [49/500], Train Loss: 0.0010, Val Loss: 0.0005
# Epoch [50/500], Train Loss: 0.0010, Val Loss: 0.0002
# Epoch [51/500], Train Loss: 0.0011, Val Loss: 0.0001
# Epoch [52/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [53/500], Train Loss: 0.0009, Val Loss: 0.0004
# Epoch [54/500], Train Loss: 0.0010, Val Loss: 0.0004
# Epoch [55/500], Train Loss: 0.0011, Val Loss: 0.0004
# Epoch [56/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [57/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [58/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [59/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [60/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [61/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [62/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [63/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [64/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [65/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [66/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [67/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [68/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [69/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [70/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [71/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [72/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [73/500], Train Loss: 0.0010, Val Loss: 0.0004
# Epoch [74/500], Train Loss: 0.0010, Val Loss: 0.0001
# Epoch [75/500], Train Loss: 0.0010, Val Loss: 0.0001
# Epoch [76/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [77/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [78/500], Train Loss: 0.0010, Val Loss: 0.0003
# Epoch [79/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [80/500], Train Loss: 0.0010, Val Loss: 0.0002
# Epoch [81/500], Train Loss: 0.0009, Val Loss: 0.0004
# Epoch [82/500], Train Loss: 0.0010, Val Loss: 0.0001
# Epoch [83/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [84/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [85/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [86/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [87/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [88/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [89/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [90/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [91/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [92/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [93/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [94/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [95/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [96/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [97/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [98/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [99/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [100/500], Train Loss: 0.0010, Val Loss: 0.0005
# Epoch [101/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [102/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [103/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [104/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [105/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [106/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [107/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [108/500], Train Loss: 0.0010, Val Loss: 0.0003
# Epoch [109/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [110/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [111/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [112/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [113/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [114/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [115/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [116/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [117/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [118/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [119/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [120/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [121/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [122/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [123/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [124/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [125/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [126/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [127/500], Train Loss: 0.0010, Val Loss: 0.0003
# Epoch [128/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [129/500], Train Loss: 0.0009, Val Loss: 0.0004
# Epoch [130/500], Train Loss: 0.0010, Val Loss: 0.0001
# Epoch [131/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [132/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [133/500], Train Loss: 0.0009, Val Loss: 0.0004
# Epoch [134/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [135/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [136/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [137/500], Train Loss: 0.0009, Val Loss: 0.0004
# Epoch [138/500], Train Loss: 0.0010, Val Loss: 0.0003
# Epoch [139/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [140/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [141/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [142/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [143/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [144/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [145/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [146/500], Train Loss: 0.0010, Val Loss: 0.0001
# Epoch [147/500], Train Loss: 0.0010, Val Loss: 0.0006
# Epoch [148/500], Train Loss: 0.0010, Val Loss: 0.0002
# Epoch [149/500], Train Loss: 0.0010, Val Loss: 0.0001
# Epoch [150/500], Train Loss: 0.0010, Val Loss: 0.0002
# Epoch [151/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [152/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [153/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [154/500], Train Loss: 0.0009, Val Loss: 0.0005
# Epoch [155/500], Train Loss: 0.0011, Val Loss: 0.0001
# Epoch [156/500], Train Loss: 0.0028, Val Loss: 0.0006
# Epoch [157/500], Train Loss: 0.0016, Val Loss: 0.0008
# Epoch [158/500], Train Loss: 0.0011, Val Loss: 0.0004
# Epoch [159/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [160/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [161/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [162/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [163/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [164/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [165/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [166/500], Train Loss: 0.0009, Val Loss: 0.0004
# Epoch [167/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [168/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [169/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [170/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [171/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [172/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [173/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [174/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [175/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [176/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [177/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [178/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [179/500], Train Loss: 0.0025, Val Loss: 0.0015
# Epoch [180/500], Train Loss: 0.0015, Val Loss: 0.0003
# Epoch [181/500], Train Loss: 0.0010, Val Loss: 0.0001
# Epoch [182/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [183/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [184/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [185/500], Train Loss: 0.0009, Val Loss: 0.0005
# Epoch [186/500], Train Loss: 0.0009, Val Loss: 0.0004
# Epoch [187/500], Train Loss: 0.0010, Val Loss: 0.0001
# Epoch [188/500], Train Loss: 0.0010, Val Loss: 0.0003
# Epoch [189/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [190/500], Train Loss: 0.0009, Val Loss: 0.0006
# Epoch [191/500], Train Loss: 0.0010, Val Loss: 0.0005
# Epoch [192/500], Train Loss: 0.0010, Val Loss: 0.0004
# Epoch [193/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [194/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [195/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [196/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [197/500], Train Loss: 0.0009, Val Loss: 0.0004
# Epoch [198/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [199/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [200/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [201/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [202/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [203/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [204/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [205/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [206/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [207/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [208/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [209/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [210/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [211/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [212/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [213/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [214/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [215/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [216/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [217/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [218/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [219/500], Train Loss: 0.0009, Val Loss: 0.0005
# Epoch [220/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [221/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [222/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [223/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [224/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [225/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [226/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [227/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [228/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [229/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [230/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [231/500], Train Loss: 0.0010, Val Loss: 0.0004
# Epoch [232/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [233/500], Train Loss: 0.0010, Val Loss: 0.0001
# Epoch [234/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [235/500], Train Loss: 0.0026, Val Loss: 0.0007
# Epoch [236/500], Train Loss: 0.0016, Val Loss: 0.0002
# Epoch [237/500], Train Loss: 0.0010, Val Loss: 0.0004
# Epoch [238/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [239/500], Train Loss: 0.0009, Val Loss: 0.0006
# Epoch [240/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [241/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [242/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [243/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [244/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [245/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [246/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [247/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [248/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [249/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [250/500], Train Loss: 0.0026, Val Loss: 0.0008
# Epoch [251/500], Train Loss: 0.0016, Val Loss: 0.0004
# Epoch [252/500], Train Loss: 0.0010, Val Loss: 0.0004
# Epoch [253/500], Train Loss: 0.0010, Val Loss: 0.0005
# Epoch [254/500], Train Loss: 0.0009, Val Loss: 0.0004
# Epoch [255/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [256/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [257/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [258/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [259/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [260/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [261/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [262/500], Train Loss: 0.0010, Val Loss: 0.0004
# Epoch [263/500], Train Loss: 0.0010, Val Loss: 0.0001
# Epoch [264/500], Train Loss: 0.0009, Val Loss: 0.0004
# Epoch [265/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [266/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [267/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [268/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [269/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [270/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [271/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [272/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [273/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [274/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [275/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [276/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [277/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [278/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [279/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [280/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [281/500], Train Loss: 0.0009, Val Loss: 0.0005
# Epoch [282/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [283/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [284/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [285/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [286/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [287/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [288/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [289/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [290/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [291/500], Train Loss: 0.0010, Val Loss: 0.0003
# Epoch [292/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [293/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [294/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [295/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [296/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [297/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [298/500], Train Loss: 0.0009, Val Loss: 0.0004
# Epoch [299/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [300/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [301/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [302/500], Train Loss: 0.0008, Val Loss: 0.0008
# Epoch [303/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [304/500], Train Loss: 0.0025, Val Loss: 0.0013
# Epoch [305/500], Train Loss: 0.0016, Val Loss: 0.0005
# Epoch [306/500], Train Loss: 0.0010, Val Loss: 0.0005
# Epoch [307/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [308/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [309/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [310/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [311/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [312/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [313/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [314/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [315/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [316/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [317/500], Train Loss: 0.0008, Val Loss: 0.0004
# Epoch [318/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [319/500], Train Loss: 0.0024, Val Loss: 0.0012
# Epoch [320/500], Train Loss: 0.0016, Val Loss: 0.0006
# Epoch [321/500], Train Loss: 0.0010, Val Loss: 0.0002
# Epoch [322/500], Train Loss: 0.0009, Val Loss: 0.0004
# Epoch [323/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [324/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [325/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [326/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [327/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [328/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [329/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [330/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [331/500], Train Loss: 0.0024, Val Loss: 0.0008
# Epoch [332/500], Train Loss: 0.0013, Val Loss: 0.0004
# Epoch [333/500], Train Loss: 0.0011, Val Loss: 0.0005
# Epoch [334/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [335/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [336/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [337/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [338/500], Train Loss: 0.0009, Val Loss: 0.0001
# Epoch [339/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [340/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [341/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [342/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [343/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [344/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [345/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [346/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [347/500], Train Loss: 0.0008, Val Loss: 0.0004
# Epoch [348/500], Train Loss: 0.0009, Val Loss: 0.0005
# Epoch [349/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [350/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [351/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [352/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [353/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [354/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [355/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [356/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [357/500], Train Loss: 0.0023, Val Loss: 0.0007
# Epoch [358/500], Train Loss: 0.0014, Val Loss: 0.0002
# Epoch [359/500], Train Loss: 0.0023, Val Loss: 0.0009
# Epoch [360/500], Train Loss: 0.0014, Val Loss: 0.0002
# Epoch [361/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [362/500], Train Loss: 0.0008, Val Loss: 0.0005
# Epoch [363/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [364/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [365/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [366/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [367/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [368/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [369/500], Train Loss: 0.0007, Val Loss: 0.0001
# Epoch [370/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [371/500], Train Loss: 0.0008, Val Loss: 0.0004
# Epoch [372/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [373/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [374/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [375/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [376/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [377/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [378/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [379/500], Train Loss: 0.0008, Val Loss: 0.0001
# Epoch [380/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [381/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [382/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [383/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [384/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [385/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [386/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [387/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [388/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [389/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [390/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [391/500], Train Loss: 0.0022, Val Loss: 0.0007
# Epoch [392/500], Train Loss: 0.0013, Val Loss: 0.0008
# Epoch [393/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [394/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [395/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [396/500], Train Loss: 0.0008, Val Loss: 0.0006
# Epoch [397/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [398/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [399/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [400/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [401/500], Train Loss: 0.0020, Val Loss: 0.0008
# Epoch [402/500], Train Loss: 0.0011, Val Loss: 0.0003
# Epoch [403/500], Train Loss: 0.0010, Val Loss: 0.0003
# Epoch [404/500], Train Loss: 0.0009, Val Loss: 0.0002
# Epoch [405/500], Train Loss: 0.0009, Val Loss: 0.0003
# Epoch [406/500], Train Loss: 0.0008, Val Loss: 0.0004
# Epoch [407/500], Train Loss: 0.0008, Val Loss: 0.0004
# Epoch [408/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [409/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [410/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [411/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [412/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [413/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [414/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [415/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [416/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [417/500], Train Loss: 0.0019, Val Loss: 0.0004
# Epoch [418/500], Train Loss: 0.0010, Val Loss: 0.0003
# Epoch [419/500], Train Loss: 0.0009, Val Loss: 0.0007
# Epoch [420/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [421/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [422/500], Train Loss: 0.0007, Val Loss: 0.0003
# Epoch [423/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [424/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [425/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [426/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [427/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [428/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [429/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [430/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [431/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [432/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [433/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [434/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [435/500], Train Loss: 0.0008, Val Loss: 0.0003
# Epoch [436/500], Train Loss: 0.0008, Val Loss: 0.0005
# Epoch [437/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [438/500], Train Loss: 0.0007, Val Loss: 0.0003
# Epoch [439/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [440/500], Train Loss: 0.0007, Val Loss: 0.0004
# Epoch [441/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [442/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [443/500], Train Loss: 0.0006, Val Loss: 0.0002
# Epoch [444/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [445/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [446/500], Train Loss: 0.0007, Val Loss: 0.0003
# Epoch [447/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [448/500], Train Loss: 0.0006, Val Loss: 0.0002
# Epoch [449/500], Train Loss: 0.0006, Val Loss: 0.0002
# Epoch [450/500], Train Loss: 0.0007, Val Loss: 0.0005
# Epoch [451/500], Train Loss: 0.0007, Val Loss: 0.0003
# Epoch [452/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [453/500], Train Loss: 0.0006, Val Loss: 0.0002
# Epoch [454/500], Train Loss: 0.0007, Val Loss: 0.0005
# Epoch [455/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [456/500], Train Loss: 0.0006, Val Loss: 0.0002
# Epoch [457/500], Train Loss: 0.0006, Val Loss: 0.0003
# Epoch [458/500], Train Loss: 0.0014, Val Loss: 0.0002
# Epoch [459/500], Train Loss: 0.0011, Val Loss: 0.0005
# Epoch [460/500], Train Loss: 0.0011, Val Loss: 0.0005
# Epoch [461/500], Train Loss: 0.0012, Val Loss: 0.0005
# Epoch [462/500], Train Loss: 0.0010, Val Loss: 0.0015
# Epoch [463/500], Train Loss: 0.0011, Val Loss: 0.0005
# Epoch [464/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [465/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [466/500], Train Loss: 0.0007, Val Loss: 0.0006
# Epoch [467/500], Train Loss: 0.0007, Val Loss: 0.0003
# Epoch [468/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [469/500], Train Loss: 0.0015, Val Loss: 0.0002
# Epoch [470/500], Train Loss: 0.0008, Val Loss: 0.0004
# Epoch [471/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [472/500], Train Loss: 0.0006, Val Loss: 0.0002
# Epoch [473/500], Train Loss: 0.0006, Val Loss: 0.0002
# Epoch [474/500], Train Loss: 0.0006, Val Loss: 0.0004
# Epoch [475/500], Train Loss: 0.0008, Val Loss: 0.0004
# Epoch [476/500], Train Loss: 0.0006, Val Loss: 0.0002
# Epoch [477/500], Train Loss: 0.0006, Val Loss: 0.0002
# Epoch [478/500], Train Loss: 0.0006, Val Loss: 0.0002
# Epoch [479/500], Train Loss: 0.0005, Val Loss: 0.0002
# Epoch [480/500], Train Loss: 0.0007, Val Loss: 0.0003
# Epoch [481/500], Train Loss: 0.0005, Val Loss: 0.0002
# Epoch [482/500], Train Loss: 0.0005, Val Loss: 0.0002
# Epoch [483/500], Train Loss: 0.0005, Val Loss: 0.0002
# Epoch [484/500], Train Loss: 0.0006, Val Loss: 0.0002
# Epoch [485/500], Train Loss: 0.0005, Val Loss: 0.0002
# Epoch [486/500], Train Loss: 0.0005, Val Loss: 0.0002
# Epoch [487/500], Train Loss: 0.0006, Val Loss: 0.0006
# Epoch [488/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [489/500], Train Loss: 0.0007, Val Loss: 0.0005
# Epoch [490/500], Train Loss: 0.0005, Val Loss: 0.0003
# Epoch [491/500], Train Loss: 0.0005, Val Loss: 0.0002
# Epoch [492/500], Train Loss: 0.0006, Val Loss: 0.0002
# Epoch [493/500], Train Loss: 0.0007, Val Loss: 0.0002
# Epoch [494/500], Train Loss: 0.0006, Val Loss: 0.0002
# Epoch [495/500], Train Loss: 0.0005, Val Loss: 0.0002
# Epoch [496/500], Train Loss: 0.0005, Val Loss: 0.0001
# Epoch [497/500], Train Loss: 0.0008, Val Loss: 0.0002
# Epoch [498/500], Train Loss: 0.0005, Val Loss: 0.0002
# Epoch [499/500], Train Loss: 0.0005, Val Loss: 0.0002
# Epoch [500/500], Train Loss: 0.0007, Val Loss: 0.0003

# %%
# test accuracy

model.eval()
with torch.no_grad():

    test_outputs = model(X_val_tensor)
    mse = mean_squared_error(y_val_tensor.cpu(), test_outputs.cpu())
    rmse = math.sqrt(mse)
    
    print(f'MSE: {mse:.4f}')
    print(f'RMSE: {rmse:.4f}')
# Out:
# MSE: 0.0003
# RMSE: 0.0165

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


model.eval()

N = 30
X_input = scaled_data[-N:].reshape(1, N, len(features))  # reshape to (1, 30, 5)

X_input_tensor = torch.tensor(X_input, dtype=torch.float32).to(device)

predicted_prices = []
with torch.no_grad():
    for i in range(31):  
        predicted_price = model(X_input_tensor)  
        predicted_price = predicted_price.cpu().numpy()
        
        # denormalize 
        predicted_close_rescaled = close_scaler.inverse_transform(predicted_price)  
        predicted_prices.append(predicted_close_rescaled[0, 0])  
        
        # update window
        X_input = np.roll(X_input, shift=-1, axis=1)
        X_input[0, -1, -1] = predicted_price[0, -1] 
        X_input_tensor = torch.tensor(X_input, dtype=torch.float32).to(device)

test_data = pd.read_csv('D:/Study/7318/a3/Recurrent-Neural-Networks-for-Stock-Price-Prediction/datasets/Google_Stock_Price_Test.csv')
test_data['Date'] = pd.to_datetime(test_data['Date'])
test_data.set_index('Date', inplace=True)

# Get the actual prices from the test dataset
actual_prices = test_data['Close'].values
actual_dates = test_data.index

# Trim the predicted prices to match the length of actual test data
predicted_prices_trimmed = predicted_prices[:len(test_data.index)]

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(actual_dates, actual_prices, label='Actual Prices', color='blue', marker='o')
plt.plot(actual_dates, predicted_prices_trimmed, label='Predicted Prices', color='red', marker='x')
plt.title('Predicted vs Actual Close Prices for January 2017 (GRU)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# create dataframe
results = pd.DataFrame({
    'Date': test_data.index[:len(predicted_prices)],  # Ensure we match the length of predicted prices
    'Predicted Close': predicted_prices[:len(test_data.index)],  # Limit predictions to the length of actual data
    'Actual Close': actual_prices[:len(test_data.index)]  # Use actual closing prices
})

# calculate trend match
results['Trend Match'] = results.apply(
    lambda row: 'Match' if (
        (row['Predicted Close'] > row['Actual Close'] and results.iloc[row.name - 1]['Actual Close'] < row['Actual Close']) or
        (row['Predicted Close'] < row['Actual Close'] and results.iloc[row.name - 1]['Actual Close'] > row['Actual Close'])
    ) else 'Mismatch', axis=1
)


print(results)

matches = results['Trend Match'].value_counts().get('Match', 0)
mismatches = results['Trend Match'].value_counts().get('Mismatch', 0)
total = len(results)
accuracy = (matches / total) * 100

print(f"\nTrend Match Analysis:")
print(f"Total Predictions: {total}")
print(f"Matches: {matches}")
print(f"Mismatches: {mismatches}")
print(f"Trend Match Accuracy: {accuracy:.2f}%")
# Out:
#          Date  Predicted Close  Actual Close Trend Match
# 0  2017-01-03       770.130798        786.14       Match
# 1  2017-01-04       766.174316        786.90    Mismatch
# 2  2017-01-05       761.987793        794.02    Mismatch
# 3  2017-01-06       768.183655        806.15    Mismatch
# 4  2017-01-09       770.227966        806.65    Mismatch
# 5  2017-01-10       761.970032        804.79       Match
# 6  2017-01-11       763.667236        807.91    Mismatch
# 7  2017-01-12       767.287170        806.36       Match
# 8  2017-01-13       773.294495        807.88    Mismatch
# 9  2017-01-17       759.796448        804.61       Match
# 10 2017-01-18       752.161072        806.07    Mismatch
# 11 2017-01-19       751.715942        802.17       Match
# 12 2017-01-20       761.251099        805.02    Mismatch
# 13 2017-01-23       760.409851        819.31    Mismatch
# 14 2017-01-24       770.891357        823.87    Mismatch
# 15 2017-01-25       778.611511        835.67    Mismatch
# 16 2017-01-26       792.458374        832.15       Match
# 17 2017-01-27       790.949646        823.31       Match
# 18 2017-01-30       800.020630        802.32       Match
# 19 2017-01-31       796.738953        796.79       Match
#
# Trend Match Analysis:
# Total Predictions: 20
# Matches: 9
# Mismatches: 11
# Trend Match Accuracy: 45.00%

# %%
# train vanilla RNN model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# init vanilla model
class VanillaRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(VanillaRNN, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        out, _ = self.rnn(x)
        out = self.fc(out[:, -1, :])  # use the last output
        return out

# Set para.
input_size = len(features)  
hidden_size = 64  
output_size = 1  
epoch = 500
learning_rate = 0.001

# loss function and optimizer
model = VanillaRNN(input_size, hidden_size, output_size).to(device)
criterion = nn.MSELoss()  # Mean Squared Error Loss
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).to(device)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32).to(device)


# train
for e in range(epoch):
    model.train()
    
    optimizer.zero_grad()
    
    outputs = model(X_train_tensor)
    
    loss = criterion(outputs, y_train_tensor)
    
    loss.backward()
    optimizer.step()
    
    if (e + 1) % 10 == 0:
        print(f"Epoch [{e+1}/{epoch}], Loss: {loss.item():.4f}")

# save model
torch.save(model.state_dict(), 'vanilla_model.pth') 

model.eval()
with torch.no_grad():
    val_outputs = model(X_val_tensor)
    mse = mean_squared_error(y_val_tensor.cpu(), val_outputs.cpu())
    rmse = math.sqrt(mse)

    print(f'MSE: {mse:.4f}')
    print(f'RMSE: {rmse:.4f}')

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
model = VanillaRNN(input_size, hidden_size, output_size).to(device)
model.load_state_dict(torch.load("vanilla_model.pth"))

model.eval()

N = 30
X_input = scaled_data[-N:].reshape(1, N, len(features))  # reshape to (1, 30, 5)

# onvert to tensor
X_input_tensor = torch.tensor(X_input, dtype=torch.float32).to(device)

# predict 
predicted_prices = []
with torch.no_grad():
    for i in range(31):  # predict from 1/2 to 1/31
        # predict
        predicted_price = model(X_input_tensor)  
        predicted_price = predicted_price.cpu().numpy()  
        
        # denormolization
        predicted_close_rescaled = close_scaler.inverse_transform(predicted_price)  
        predicted_prices.append(predicted_close_rescaled[0, 0])  
        
        # update window
        X_input = np.roll(X_input, -1, axis=1)  
        X_input[0, -1, -1] = predicted_price[0, -1] 

        # X_input[0, -1, 0:-1] = X_input[0, -2, 0:-1] 
        X_input_tensor = torch.Tensor(X_input).to(device)


# load actual data
test_data = pd.read_csv('D:/Study/7318/a3/Recurrent-Neural-Networks-for-Stock-Price-Prediction/datasets/Google_Stock_Price_Test.csv')
test_data['Date'] = pd.to_datetime(test_data['Date'])
test_data.set_index('Date', inplace=True)

actual_prices = test_data['Close'].values
actual_dates = test_data.index

predicted_prices_trimmed = predicted_prices[:len(test_data.index)]

# plot
plt.figure(figsize=(12, 6))
plt.plot(actual_dates, actual_prices, label='Actual Prices', color='blue', marker='o')
plt.plot(actual_dates, predicted_prices_trimmed, label='Predicted Prices', color='red', marker='x')
plt.title('Predicted vs Actual Close Prices for January 2017 (Vanilla RNN)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# C:\Users\SpiderJockey\AppData\Local\Temp\ipykernel_22136\1739035404.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("vanilla_model.pth"))

# %%
import pandas as pd
import matplotlib.pyplot as plt

# create dataframe
results = pd.DataFrame({
    'Date': test_data.index[:len(predicted_prices)],  # Ensure we match the length of predicted prices
    'Predicted Close': predicted_prices[:len(test_data.index)],  # Limit predictions to the length of actual data
    'Actual Close': actual_prices[:len(test_data.index)]  # Use actual closing prices
})

# calculate trend match
results['Trend Match'] = results.apply(
    lambda row: 'Match' if (
        (row['Predicted Close'] > row['Actual Close'] and results.iloc[row.name - 1]['Actual Close'] < row['Actual Close']) or
        (row['Predicted Close'] < row['Actual Close'] and results.iloc[row.name - 1]['Actual Close'] > row['Actual Close'])
    ) else 'Mismatch', axis=1
)


print(results)

matches = results['Trend Match'].value_counts().get('Match', 0)
mismatches = results['Trend Match'].value_counts().get('Mismatch', 0)
total = len(results)
accuracy = (matches / total) * 100

print(f"\nTrend Match Analysis:")
print(f"Total Predictions: {total}")
print(f"Matches: {matches}")
print(f"Mismatches: {mismatches}")
print(f"Trend Match Accuracy: {accuracy:.2f}%")
# Out:
#          Date  Predicted Close  Actual Close Trend Match
# 0  2017-01-03       778.496216        786.14       Match
# 1  2017-01-04       771.449402        786.90    Mismatch
# 2  2017-01-05       765.453491        794.02    Mismatch
# 3  2017-01-06       762.698608        806.15    Mismatch
# 4  2017-01-09       765.759521        806.65    Mismatch
# 5  2017-01-10       765.707581        804.79       Match
# 6  2017-01-11       763.247437        807.91    Mismatch
# 7  2017-01-12       764.467773        806.36       Match
# 8  2017-01-13       768.077820        807.88    Mismatch
# 9  2017-01-17       766.591919        804.61       Match
# 10 2017-01-18       756.226807        806.07    Mismatch
# 11 2017-01-19       746.872131        802.17       Match
# 12 2017-01-20       751.038452        805.02    Mismatch
# 13 2017-01-23       759.166077        819.31    Mismatch
# 14 2017-01-24       766.987549        823.87    Mismatch
# 15 2017-01-25       774.929260        835.67    Mismatch
# 16 2017-01-26       784.564941        832.15       Match
# 17 2017-01-27       790.836792        823.31       Match
# 18 2017-01-30       795.839966        802.32       Match
# 19 2017-01-31       797.594055        796.79    Mismatch
#
# Trend Match Analysis:
# Total Predictions: 20
# Matches: 8
# Mismatches: 12
# Trend Match Accuracy: 40.00%
